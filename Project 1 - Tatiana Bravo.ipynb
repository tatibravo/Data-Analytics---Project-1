# %%
import pandas as pd
import numpy as np

# %%
DC_properties_df = pd.read_csv("datasets/DC_Properties.csv")
DC_properties_df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
DC_properties_df.dtypes;

# %%
DC_properties_df.drop(['STORIES', 'NUM_UNITS', 'SALEDATE', 'Unnamed: 0', 'SALE_NUM','QUALIFIED','BLDG_NUM','STYLE'], axis=1, inplace = True)

# %%
DC_price = DC_properties_df[DC_properties_df['PRICE'].notnull()]

# %%
DC_price.shape
# Out:
# (98216, 41)

# %%
DC_realRM_price = DC_price[DC_price['BEDRM']!= 0]
DC_realRM_price.shape
# Out:
# (94405, 41)

# %%
DC_real_Count_price = DC_realRM_price[DC_realRM_price['BATHRM']!= 0]
DC_real_Count_price.shape
# Out:
# (94399, 41)

# %%
DC_real_Count_price.columns
# Out:
# Index(['BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'ROOMS', 'BEDRM', 'AYB', 'YR_RMDL',
#        'EYB', 'PRICE', 'GBA', 'STRUCT', 'GRADE', 'CNDTN', 'EXTWALL', 'ROOF',
#        'INTWALL', 'KITCHENS', 'FIREPLACES', 'USECODE', 'LANDAREA',
#        'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM', 'LIVING_GBA', 'FULLADDRESS',
#        'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID', 'LATITUDE', 'LONGITUDE',
#        'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT', 'CENSUS_BLOCK',
#        'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
pd.pivot_table(DC_real_Count_price, values=['PRICE'], index=['BEDRM','BATHRM'])
# Out:
#                      PRICE
# BEDRM BATHRM
# 1     1       1.887415e+06
#       2       2.753084e+06
#       3       6.520667e+05
#       4       2.539750e+05
# 2     1       4.706987e+05
#       2       7.829985e+05
#       3       7.162117e+05
#       4       8.532768e+05
# 3     1       3.094116e+05
#       2       5.031922e+05
#       3       7.185585e+05
#       4       1.013861e+06
#       5       2.219800e+06
#       6       4.000000e+05
#       7       4.217000e+06
# 4     1       3.397873e+05
#       2       5.151250e+05
#       3       7.792648e+05
#       4       7.937731e+05
#       5       1.825532e+06
#       6       2.264856e+06
#       7       2.450000e+06
#       8       7.500000e+05
# 5     1       3.672648e+05
#       2       5.810937e+05
#       3       8.937884e+05
#       4       1.282628e+06
#       5       1.770525e+06
#       6       2.704656e+06
#       7       2.580000e+06
# ...                    ...
# 9     3       5.789950e+05
# ...

# %%
DC_real_Count_price['PRICE'].max()
# Out:
# 137427545.0

# %%
DC_real_Count_price['PRICE'].median()
# Out:
# 415000.0

# %%
DC_real_Count_price['PRICE'].mode()
# Out:
# 0    350000.0
# dtype: float64

# %%
DC_real_Count_price['BEDRM'].median()
# Out:
# 3.0

# %%
DC_real_Count_price['BEDRM'].mode()
# Out:
# 0    3
# dtype: int64

# %%
DC_real_Count_price['BATHRM'].median()
# Out:
# 2.0

# %%
DC_real_Count_price['BATHRM'].mode()
# Out:
# 0    1
# dtype: int64

# %%
DC_real_Count_price.describe()
# Out:
#              BATHRM     HF_BATHRM         ROOMS         BEDRM           AYB  \
# count  94399.000000  94399.000000  94399.000000  94399.000000  94289.000000
# mean       1.893897      0.462081      6.077310      2.711713   1944.453287
# std        0.981790      0.580425      2.570125      1.317508     36.312240
# min        1.000000      0.000000      1.000000      1.000000   1754.000000
# 25%        1.000000      0.000000      4.000000      2.000000   1917.000000
# 50%        2.000000      0.000000      6.000000      3.000000   1938.000000
# 75%        2.000000      1.000000      7.000000      3.000000   1965.000000
# max       12.000000     11.000000     31.000000     20.000000   2018.000000
#
#             YR_RMDL           EYB         PRICE           GBA      KITCHENS  \
# count  54849.000000  94399.000000  9.439900e+04  57827.000000  57826.000000
# mean    2001.279185   1966.119747  8.885202e+05   1726.142269      1.251392
# ...
